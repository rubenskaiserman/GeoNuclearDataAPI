# %%
import pandas as pd
from matplotlib import pyplot as plt

df = pd.read_csv('./data/data.csv')

agrupado = df.groupby(['reactor_type', 'status'])
display(agrupado.size())

reactor_types = df['reactor_type'].unique()
status = df['status'].unique()

# Compare the number of reactors by type and status
for reactor_type in reactor_types:
    df_reactor_type = df[df['reactor_type'] == reactor_type]
    x = df_reactor_type['status'].unique()
    y = [df_reactor_type[df_reactor_type['status'] == status]['status'].count() for status in x]
    
    plt.bar(x, y)
    plt.title(reactor_type)
    plt.xticks(rotation=-90)
    plt.show()
# Out:
# reactor_type  status
# ABWR          Planned                        6
# APWR          Planned                        1
# BWR           Decommissioning Completed      2
#               Never Commissioned             1
#               Operational                   41
#               Shutdown                      53
#               Suspended Construction         2
#               Suspended Operation           19
#               Under Construction             2
# FBR           Never Commissioned             1
#               Operational                    3
#               Planned                        3
#               Shutdown                       8
#               Under Construction             4
# GCR           Operational                    8
#               Shutdown                      44
# HTGR          Operational                    1
#               Shutdown                       4
# HWGCR         Decommissioning Completed      1
#               Shutdown                       3
# HWLWR         Shutdown                       2
# LWGR          Cancelled Construction         1
#               Operational                   11
#               Shutdown                      13
# OCR           Shutdown                       2
# PHWR          Cancelled Construction         1
#               Operational                   46
#               Planned                       10
#               Shutdown                      10
#               Suspended Construction         2
#               Suspended Operation            2
#               Under Construction             3
# PWR           Cancelled Construction         2
#               Operational                  301
#               Planned                       51
#               Shutdown                      69
#               Suspended Construction         2
#               Suspended Operation            6
#               Under Construction            51
#               Unknown                        1
# SGHWR         Shutdown                       1
# dtype: int64
